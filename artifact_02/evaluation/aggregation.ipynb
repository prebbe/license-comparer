// %% [markdown]
// # Aggregation
// In this notebook we will evaluate the results of the aggregation logic. Let's start by listing the checked license.

// %%
const db = require('../dist/dataAccess.js');
const tslab = require('tslab');

let licenses = await db.loadLicenses();

let html = [];
html.push("<div style='display:flex;flex-wrap:wrap;'>");
html.push("<table>");
html.push("<tr><th>Id</th><th>Name</th><th>ShortName</th><th>SourceLink</th><th>Description</th></tr>")
for (let i = 0; i < licenses.length; i++) {
    let l = licenses[i];
    let row = `
    <tr>
        <td>${l.id}</td>
        <td>${l.name}</td>
        <td>${l.shortName}</td>
        <td>${l.sourceLink}</td>
        <td>${l.description}</td>
    </tr>`; 
        
    html.push(row);
}
html.push("</table>");
html.push("</div>");

tslab.display.html(html.join('\n'));
// Out:
// <div style='display:flex;flex-wrap:wrap;'>
// <table>
// <tr><th>Id</th><th>Name</th><th>ShortName</th><th>SourceLink</th><th>Description</th></tr>
//
//     <tr>
//         <td>0</td>
//         <td>Creative Commons Attribution License 4.0</td>
//         <td>CC-BY-4.0</td>
//         <td>https://creativecommons.org/licenses/by/4.0/legalcode.de</td>
//         <td>null</td>
//     </tr>
//
//     <tr>
//         <td>1</td>
//         <td>Creative Commons Attribution-ShareAlike License 4.0</td>
//         <td>CC-BY-SA-4.0</td>
//         <td>https://creativecommons.org/licenses/by-sa/4.0/legalcode.de</td>
//         <td>null</td>
//     </tr>
//
//     <tr>
//         <td>2</td>
//         <td>Creative Commons Attribution-NoDerivatives License 4.0</td>
//         <td>CC-BY-ND-4.0</td>
//         <td>https://creativecommons.org/licenses/by-nd/4.0/legalcode.de</td>
//         <td>null</td>
//     </tr>
//
//     <tr>
//         <td>3</td>
//         <td>Creative Commons Attribution-NonCommercial License 4.0</td>
//         <td>CC-BY-NC-4.0</td>
//         <td>https://creativecommons.org/licenses/by-nc/4.0/legalcode.de</td>
//         <td>null</td>
//     </tr>
//
//     <tr>
//         <td>4</td>
//         <td>Creative Commons Attribution-NonCommercial-ShareAlike License 4.0</td>
//         <td>CC-BY-NC-SA-4.0</td>
//         <td>https://creativecommons.org/licenses/by-nc-sa/4.0/legalcode.de</td>
//         <td>null</td>
//     </tr>
//
//     <tr>
//         <td>5</td>
//         <td>Creative Commons Attribution-NonCommercial-NoDerivatives License 4.0</td>
//         <td>CC-BY-NC-ND-4.0</td>
//         <td>https://creativecommons.org/licenses/by-nc-nd/4.0/legalcode.de</td>
//         <td>null</td>
//     </tr>
//
//     <tr>
//         <td>6</td>
//         <td>Creative Commons Zero</td>
//         <td>CC0</td>
//         <td>https://creativecommons.org/publicdomain/zero/1.0/legalcode.de</td>
//         <td>null</td>
//     </tr>
//
//     <tr>
//         <td>7</td>
//         <td>Open Data Commons Attribution License v1.0</td>
//         <td>ODC-By-1.0</td>
//         <td>https://opendatacommons.org/licenses/by/1-0/</td>
//         <td>null</td>
//     </tr>
//
//     <tr>
//         <td>8</td>
//         <td>Open Data Commons Public Domain Dedication and License v1.0</td>
//         <td>PDDL-1.0</td>
//         <td>https://opendatacommons.org/licenses/pddl/1-0/</td>
//         <td>null</td>
//     </tr>
//
//     <tr>
//         <td>9</td>
//         <td>Open Data Commons Open Database License v1.0</td>
//         <td>ODbL-1.0</td>
//         <td>https://opendatacommons.org/licenses/odbl/1-0/</td>
//         <td>null</td>
//     </tr>
//
//     <tr>
//         <td>10</td>
//         <td>Data licence Germany - attribution - version 2.0</td>
//         <td>DL-DE-BY-2.0</td>
//         <td>https://www.govdata.de/dl-de/by-2-0</td>
//         <td>null</td>
//     </tr>
//
//     <tr>
//         <td>11</td>
//         <td>Data licence Germany - Zero - Version 2.0</td>
//         <td>DL-DE-ZERO-2.0</td>
//         <td>https://www.govdata.de/dl-de/zero-2-0</td>
//         <td>null</td>
//     </tr>
//
//     <tr>
//         <td>12</td>
//         <td>Open Government License (for Public Sector Information)</td>
//         <td>OGL-UK-3.0</td>
//         <td>https://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/</td>
//         <td>null</td>
//     </tr>
//
//     <tr>
//         <td>13</td>
//         <td>Singapore Open Data License</td>
//         <td>null</td>
//         <td>https://beta.data.gov.sg/open-data-license</td>
//         <td>null</td>
//     </tr>
//
//     <tr>
//         <td>14</td>
//         <td>Open License</td>
//         <td>etalab-2.0</td>
//         <td>https://www.etalab.gouv.fr/wp-content/uploads/2014/05/Open_Licence.pdf</td>
//         <td>null</td>
//     </tr>
//
//     <tr>
//         <td>15</td>
//         <td>Norwegian Licence for Open Government Data 2.0</td>
//         <td>NLOD-2.0</td>
//         <td>https://data.norge.no/nlod/en/2.0</td>
//         <td>null</td>
//     </tr>
//
//     <tr>
//         <td>16</td>
//         <td>Open Use of Data Agreement v1.0</td>
//         <td>O-UDA-1.0</td>
//         <td>https://cdla.dev/open-use-of-data-agreement-v1-0/</td>
//         <td>null</td>
//     </tr>
//
//     <tr>
//         <td>17</td>
//         <td>Community Data License Agreement - Permissive - Version 2.0</td>
//         <td>CDLA-Permissive-2.0</td>
//         <td>https://cdla.dev/permissive-2-0/</td>
//         <td>null</td>
//     </tr>
//
//     <tr>
//         <td>18</td>
//         <td>Community Data License Agreement - Sharing - Version 1.0</td>
//         <td>CDLA-Sharing-1.0</td>
//         <td>https://cdla.dev/sharing-1-0/</td>
//         <td>null</td>
//     </tr>
// </table>
// </div>

// %% [markdown]
// Now let's have a look at the results of the aggregation logic.

// %%
const aggregator = require('../dist/index.js');
const tslab = require('tslab');

function displayActions(actions) {
    return Array.from(actions).reduce((prev, current) => prev + ', ' + current?.name ?? 'unexpected', '').substring(1);
}

function createTable(results) {
    let html = [];
    html.push("<div style='display:flex;flex-wrap:wrap;'>");
    html.push("<table>");
    let firstRow = '<tr>';  
    firstRow += '<td>License 1</td>';  
    firstRow += '<td>License 2</td>';  
    firstRow += '<td>Permissions</td>';  
    firstRow += '<td>Prohibitions</td>';  
    firstRow += '<td>Duties</td>';  
    firstRow += '</tr>';

    html.push(firstRow);
    for (let i = 0; i < results.length; i++) {
        let r = results[i];

        let permissionsText = displayActions(r.permissions);
        let prohibitionsText = displayActions(r.prohibitions);
        let dutiesText = displayActions(r.duties);
        let row = '<tr>';
        
        row += `<td>${r.license1short}</td>`;
        row += `<td>${r.license2short}</td>`;
        row += `<td>${permissionsText}</td>`;
        row += `<td>${prohibitionsText}</td>`;
        row += `<td>${dutiesText}</td>`;

        row +='</tr>';
        html.push(row);
    }
    html.push("</table>");
    html.push("</div>");

    tslab.display.html(html.join('\n'));
}

let results = await aggregator.runCompleteAggregation();

createTable(results);
// Out:
// <div style='display:flex;flex-wrap:wrap;'>
// <table>
// <tr><td>License 1</td><td>License 2</td><td>Permissions</td><td>Prohibitions</td><td>Duties</td></tr>
// <tr><td>CC-BY-4.0</td><td>CC-BY-4.0</td><td> Sharing, DerivativeWorks, Reproduce, Distribution, CommercialUse, FreeAccess, UninhibitedAccess, Relicense</td><td> ClaimWarranty, ClaimLiability, Endorse, ClaimMoralRights, ClaimTrademark, ClaimPersonalityRights, ClaimPatentRights, ClaimCopyrightRights</td><td> Attribution, Inform, Notice, LinkLicense, LinkDataSet</td></tr>
// <tr><td>CC-BY-4.0</td><td>CC-BY-SA-4.0</td><td> Sharing, DerivativeWorks, Reproduce, Distribution, CommercialUse, FreeAccess, UninhibitedAccess, Relicense</td><td> ClaimWarranty, ClaimLiability, Endorse, ClaimMoralRights, ClaimTrademark, ClaimPersonalityRights, ClaimPatentRights, ClaimCopyrightRights</td><td> Attribution, Inform, Notice, LinkLicense, LinkDataSet, ShareAlike</td></tr>
// <tr><td>CC-BY-4.0</td><td>CC-BY-ND-4.0</td><td> Sharing, Reproduce, Distribution, CommercialUse, FreeAccess, UninhibitedAccess</td><td> ClaimWarranty, ClaimLiability, Endorse, ClaimMoralRights, ClaimTrademark, ClaimPersonalityRights, ClaimPatentRights, ClaimCopyrightRights, DerivativeWorks</td><td> Attribution, Inform, Notice, LinkLicense, LinkDataSet</td></tr>
// <tr><td>CC-BY-4.0</td><td>CC-BY-NC-4.0</td><td> Sharing, DerivativeWorks, Reproduce, Distribution, FreeAccess, UninhibitedAccess, Relicense</td><td> ClaimWarranty, ClaimLiability, Endorse, ClaimMoralRights, ClaimTrademark, ClaimPersonalityRights, ClaimPatentRights, ClaimCopyrightRights, CommercialUse</td><td> Attribution, Inform, Notice, LinkLicense, LinkDataSet</td></tr>
// <tr><td>CC-BY-4.0</td><td>CC-BY-NC-SA-4.0</td><td> Sharing, DerivativeWorks, Reproduce, Distribution, FreeAccess, UninhibitedAccess, Relicense</td><td> ClaimWarranty, ClaimLiability, Endorse, ClaimMoralRights, ClaimTrademark, ClaimPersonalityRights, ClaimPatentRights, ClaimCopyrightRights, CommercialUse</td><td> Attribution, Inform, Notice, LinkLicense, LinkDataSet, ShareAlike</td></tr>
// <tr><td>CC-BY-4.0</td><td>CC-BY-NC-ND-4.0</td><td> Sharing, Reproduce, Distribution, FreeAccess, UninhibitedAccess</td><td> ClaimWarranty, ClaimLiability, Endorse, ClaimMoralRights, ClaimTrademark, ClaimPersonalityRights, ClaimPatentRights, ClaimCopyrightRights, DerivativeWorks, CommercialUse, Relicense</td><td> Attribution, Inform, Notice, LinkLicense, LinkDataSet</td></tr>
// <tr><td>CC-BY-4.0</td><td>CC0</td><td> Sharing, DerivativeWorks, Reproduce, Distribution, CommercialUse, FreeAccess, UninhibitedAccess</td><td> ClaimWarranty, ClaimLiability, Endorse, ClaimMoralRights, ClaimTrademark, ClaimPersonalityRights, ClaimPatentRights, ClaimCopyrightRights</td><td> Attribution, Inform, Notice, LinkLicense, LinkDataSet</td></tr>
// <tr><td>CC-BY-4.0</td><td>ODC-By-1.0</td><td> Sharing, DerivativeWorks, Reproduce, Distribution, CommercialUse, FreeAccess, UninhibitedAccess</td><td> ClaimWarranty, ClaimLiability, Endorse, ClaimMoralRights, ClaimTrademark, ClaimPersonalityRights, ClaimPatentRights, ClaimCopyrightRights, ClaimDataProtection, Relicense</td><td> Attribution, Inform, Notice, LinkLicense, LinkDataSet</td></tr>
// <tr><td>CC-BY-4.0</td><td>PDDL-1.0</td><td> Sharing, DerivativeWorks, Reproduce, Distribution, CommercialUse, FreeAccess, UninhibitedAccess, Relicense</td><td> ClaimWarranty, ClaimLiability, Endorse, ClaimMoralRights, ClaimTrademark, ClaimPersonalityRights, ClaimPatentRights, ClaimCopyrightRights</td><td> Attribution, Inform, Notice, LinkLicense, LinkDataSet</td></tr>
// <tr><td>CC-BY-4.0</td><td>ODbL-1.0</td><td> Sharing, DerivativeWorks, Reproduce, Distribution, CommercialUse, FreeAccess, UninhibitedAccess, Relicense</td><td> ClaimWarranty, ClaimLiability, Endorse, ClaimMoralRights, ClaimTrademark, ClaimPersonalityRights, ClaimPatentRights, ClaimCopyrightRights, ClaimDataProtection</td><td> Attribution, Inform, Notice, LinkLicense, LinkDataSet, ShareAlike</td></tr>
// <tr><td>CC-BY-4.0</td><td>DL-DE-BY-2.0</td><td> Sharing, DerivativeWorks, Reproduce, Distribution, CommercialUse</td><td> ClaimWarranty, ClaimLiability, Endorse, ClaimMoralRights, ClaimTrademark, ClaimPersonalityRights, ClaimPatentRights, ClaimCopyrightRights, Relicense</td><td> Attribution, Inform, Notice, LinkLicense, LinkDataSet</td></tr>
// <tr><td>CC-BY-4.0</td><td>DL-DE-ZERO-2.0</td><td> Sharing, DerivativeWorks, Reproduce, Distribution, CommercialUse</td><td> ClaimWarranty, ClaimLiability, Endorse, ClaimMoralRights, ClaimTrademark, ClaimPersonalityRights, ClaimPatentRights, ClaimCopyrightRights, Relicense</td><td> Attribution, Inform, Notice, LinkLicense, LinkDataSet</td></tr>
// <tr><td>CC-BY-4.0</td><td>OGL-UK-3.0</td><td> Sharing, DerivativeWorks, Reproduce, Distribution, CommercialUse, FreeAccess, UninhibitedAccess, Relicense</td><td> ClaimWarranty, ClaimLiability, Endorse, ClaimMoralRights, ClaimTrademark, ClaimPersonalityRights, ClaimPatentRights, ClaimCopyrightRights, ClaimDesignRights, ClaimPersonalData, ClaimThirdPartyRights</td><td> Attribution, Inform, Notice, LinkLicense, LinkDataSet</td></tr>
// <tr><td>CC-BY-4.0</td><td>null</td><td> Sharing, DerivativeWorks, Reproduce, Distribution, CommercialUse, FreeAccess, UninhibitedAccess</td><td> ClaimWarranty, ClaimLiability, Endorse, ClaimMoralRights, ClaimTrademark, ClaimPersonalityRights, ClaimPatentRights, ClaimCopyrightRights, ClaimDesignRights, ClaimPersonalData, ClaimThirdPartyRights, Relicense</td><td> Attribution, Inform, Notice, LinkLicense, LinkDataSet</td></tr>
// <tr><td>CC-BY-4.0</td><td>etalab-2.0</td><td> Sharing, DerivativeWorks, Reproduce, Distribution, CommercialUse, FreeAccess, UninhibitedAccess</td><td> ClaimWarranty, ClaimLiability, Endorse, ClaimMoralRights, ClaimTrademark, ClaimPersonalityRights, ClaimPatentRights, ClaimCopyrightRights</td><td> Attribution, Inform, Notice, LinkLicense, LinkDataSet</td></tr>
// <tr><td>CC-BY-4.0</td><td>NLOD-2.0</td><td> Sharing, DerivativeWorks, Reproduce, Distribution, FreeAccess, UninhibitedAccess</td><td> ClaimWarranty, ClaimLiability, Endorse, ClaimMoralRights, ClaimTrademark, ClaimPersonalityRights, ClaimPatentRights, ClaimCopyrightRights, ClaimDesignRights, ClaimPersonalData, ClaimThirdPartyRights, Relicense</td><td> Attribution, Inform, Notice, LinkLicense, LinkDataSet, LimitLicenseVersion</td></tr>
// <tr><td>CC-BY-4.0</td><td>O-UDA-1.0</td><td> Sharing, DerivativeWorks, Reproduce, Distribution, CommercialUse, Relicense</td><td> ClaimWarranty, ClaimLiability, Endorse, ClaimMoralRights, ClaimTrademark, ClaimPersonalityRights, ClaimPatentRights, ClaimCopyrightRights</td><td> Attribution, Inform, Notice, LinkLicense, LinkDataSet</td></tr>
// <tr><td>CC-BY-4.0</td><td>CDLA-Permissive-2.0</td><td> Sharing, DerivativeWorks, Reproduce, Distribution, Relicense</td><td> ClaimWarranty, ClaimLiability, Endorse, ClaimMoralRights, ClaimTrademark, ClaimPersonalityRights, ClaimPatentRights, ClaimCopyrightRights</td><td> Attribution, Inform, Notice, LinkLicense, LinkDataSet</td></tr>
// <tr><td>CC-BY-4.0</td><td>CDLA-Sharing-1.0</td><td> Sharing, DerivativeWorks, Reproduce, Distribution, FreeAccess, UninhibitedAccess</td><td> ClaimWarranty, ClaimLiability, Endorse, ClaimMoralRights, ClaimTrademark, ClaimPersonalityRights, ClaimPatentRights, ClaimCopyrightRights, Relicense</td><td> Attribution, Inform, Notice, LinkLicense, LinkDataSet</td></tr>
// <tr><td>CC-BY-SA-4.0</td><td>CC-BY-4.0</td><td> Sharing, DerivativeWorks, Reproduce, Distribution, CommercialUse, FreeAccess, UninhibitedAccess, Relicense</td><td> ClaimWarranty, ClaimLiability, Endorse, ClaimMoralRights, ClaimTrademark, ClaimPersonalityRights, ClaimPatentRights, ClaimCopyrightRights</td><td> ShareAlike, Attribution, Inform, Notice, LinkLicense, LinkDataSet</td></tr>
// <tr><td>CC-BY-SA-4.0</td><td>CC-BY-SA-4.0</td><td> Sharing, DerivativeWorks, Reproduce, Distribution, CommercialUse, FreeAccess, UninhibitedAccess, Relicense</td><td> ClaimWarranty, ClaimLiability, Endorse, ClaimMoralRights, ClaimTrademark, ClaimPersonalityRights, ClaimPatentR
